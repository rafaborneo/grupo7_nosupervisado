# %% [markdown]
# <center>
#
# ## DiploDatos: Aprendizaje No Supervisado
#
# ## Embeddings con el DataSet FIFA21

# %% [markdown]
# ## 1.Inicialización_del_Entorno

# %% [markdown]
# Empezamos importando algunas herramientas para cargar los datos y manipularlos.

# %%
import warnings

warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
from time import time

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, MeanShift, estimate_bandwidth

# %% [markdown]
# ## 2.Preparación_de_los_Datos

# %% [markdown]
# Cargamos los datos bajados de la database de [Kaggle](https://www.kaggle.com/stefanoleone992/fifa-21-complete-player-dataset) como `players_21.csv`.

# %%
df = pd.read_csv('players_21.csv')

print(f'Dimensiones: {df.shape}')
# Out:
# Dimensiones: (18944, 106)

# %%
# Variables Auxiliares.
name = 'short_name'
age = 'age'
country = 'nationality'
club = 'club_name'
league = 'league_name'
position = 'team_position'
overall = 'overall'
potential = 'potential'

description = [name, age, country, club, league, position, overall, potential]

# Variables Adicionales.
player_class = 'Player Class'
position_type = 'Position Type'
tsne_0 = 'TSNE_0'
tsne_1 = 'TSNE_1'
pca_0 = 'PCA_0'
pca_1 = 'PCA_1'
cluster_KMeans = 'KMeans'
cluster_MeanShift = 'MeanShift'

# %%
skillGroup = ('attacking',
              'defending',
              'goalkeeping',
              'skill',
              'power',
              'movement',
              'mentality')

skillRating = {}

# Veamos las habilidades con las que estamos trabajando...
for g in skillGroup:
    # Inicializamos el grupo de habilidades.
    skillRating[g] = []
    # Iteramos sobre el conjunto de columnas del DF.
    for c in df.columns[40:100]:
        if c.startswith(g):
            # Almacenamos la habilidad en el grupo.
            skillRating[g].append(c)

# %%
# Conservamos a los jugadores buenos.
minOverall = 70
bestDF = df[(df[overall] > minOverall)]

# Marcamos a los mejores jugadores.
topOverall = 85
bestDF[player_class] = bestDF[overall].apply(lambda o: 'TOP' if o > topOverall else 'Average')

# %%
# Generalizamos las posiciones de los jugadores en el juego...
goalkeepers = ['GK']
defenders = ['LCB', 'RCB', 'LB', 'RB', 'CB', 'LWB', 'RWB']
midfielders = ['LM', 'RM', 'CM', 'LCM', 'RCM', 'LDM', 'RDM', 'CDM', 'LAM', 'RAM', 'CAM']
attackers = ['ST', 'LS', 'RS', 'LW', 'RW', 'LF', 'RF', 'CF']

def general_position(position):
    if position in attackers:
        return 'Attacker'
    elif position in midfielders:
        return 'Midfielder'
    elif position in defenders:
        return 'Defender'
    elif position in goalkeepers:
        return 'Goalkeeper'
    else:
        return 'Other'

position_order = ['Goalkeeper', 'Defender', 'Midfielder', 'Attacker', 'Other']

bestDF[position_type] = bestDF[position].apply(general_position)

# %% [markdown]
# ## 3.Visualización_con_Embeddings_tSNE

# %% [markdown]
# **t-SNE: t-distributed Stochastic Neighbor Embedding**
#
# *t-SNE* es una herramienta para visualizar datos altamente dimensionales.
#
# Los proyecta en menos dimensiones (2D o 3D) manteniendo la distancia entre ellos.
#
# Consideramos: filas/observaciones $x_i$ y $x_j$ (jugador i y jugador j) en $R^n$.
#
# Comienza convirtiendo distancias entre puntos (observaciones) en probabilidades condicionales.
#
# $d(x_i, x_j) \rightarrow p(x_j | x_i)$,
#
# Y luego va acomodando puntos asociados (en el plano 2D o el espacio 3D) que ajusten las probabilidades condicionales.
#
# $x'_i$ y $x'_j$ en $R^2$  (para el jugador i y jugador j ) $p(x'_j | x'_i) \leftrightarrow d(x'_i, x'_j)$ / $p(x_j | x_i) \approx p(x'_j | x'_i)$
#
# El ajuste consiste en minimizar la divergencia **Kullback-Leibler** entre las probabilidades condicionales establecidas en el espacio de mayor dimensión y las determinadas en el espacio de menor dimensión.
#
# El modelo de distribución de probabilidad es el de *t-Student*.
#
# *t-SNE* tiene una función de costo que no es convexa, por lo cual diferentes inicializaciones pueden dar diferentes resultados.

# %%
onlySkills = []
for skills in skillRating.values():
    onlySkills += skills

# Eliminamos atributos nulos.
onlySkills.remove('defending_marking')

# Sólo con desempeños según habilidades (no vacías).
skillsDF = bestDF[onlySkills]

print(f'Dimensión del espacio de los datos: {len(onlySkills)}')
# Out:
# Dimensión del espacio de los datos: 33

# %% [markdown]
# Transformaremos el espacio de **Dim 33** en un espacio de **Dim 2** (`n_components = 2`).

# %%
time_start = time()

tsne = TSNE(n_components=2, perplexity=25, verbose=1, random_state=123)
X_tsne = tsne.fit_transform(skillsDF)

time_end = time()

print(f't-SNE done! Time elapsed: {time_end - time_start} seconds.')
# Out:
# [t-SNE] Computing 76 nearest neighbors...
# [t-SNE] Indexed 4512 samples in 0.019s...
# [t-SNE] Computed neighbors for 4512 samples in 1.113s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4512
# [t-SNE] Computed conditional probabilities for sample 2000 / 4512
# [t-SNE] Computed conditional probabilities for sample 3000 / 4512
# [t-SNE] Computed conditional probabilities for sample 4000 / 4512
# [t-SNE] Computed conditional probabilities for sample 4512 / 4512
# [t-SNE] Mean sigma: 11.934181
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.314774
# [t-SNE] KL divergence after 1000 iterations: 1.826157
# t-SNE done! Time elapsed: 36.30756664276123 seconds.

# %% [markdown]
# **El resultado (`X_tsne`) se guarda en una arreglo *numpy* de tamaño...**
#
# - Cantidad de filas `# Jugadores Buenos en DF (~ 4500)`.
#
# - Cantidad de columnas `n_components (= 2)`.

# %%
print(f'Dimensiones: {X_tsne.shape}')

X_tsne[:5] # Algunos jugadores cualquiera...
# Out:
# Dimensiones: (4512, 2)
# array([[ 48.92104  ,  14.606376 ],
#        [ 51.384037 ,  11.476695 ],
#        [ -7.7444105, -60.51396  ],
#        [ 52.64647  ,  11.556143 ],
#        [ 48.813892 ,  14.415254 ]], dtype=float32)

# %% [markdown]
# **GRAFICAMOS: Scatter Plot**
#
# Las variables que usamos para el *scatterplot* son las 2 componentes dadas por **tSNE**.
#
# Agregamos los nombres de los jugadores top (`overall` mayor a 85), y analizamos una tercera variable recorriendo los puntos sobre el gráfico.

# %%
# Diferenciamos a los mejores jugadores.
bool_TOP = bestDF[overall] > topOverall

# %%
# Graficamos los datos en el espacio transformado por las componentes TSNE.

graph = go.Scatter(x=X_tsne[:, 0],
                   y=X_tsne[:, 1],
                   name='Players',
                   mode='markers',
                   text=bestDF[position],
                   marker=dict(size=5)
                  )

top = go.Scatter(x=X_tsne[bool_TOP, 0],
                 y=X_tsne[bool_TOP, 1],
                 name='Top Players',
                 text=bestDF.loc[bool_TOP, name],
                 textfont=dict(family='sans serif', size=8, color='black'),
                 opacity=0.9,
                 mode='text'
                )

data = [graph, top]

layout = go.Layout(title='t-SNE - FIFA Players',
                   titlefont=dict(size=20),
                   xaxis=dict(title='Componente 0'),
                   yaxis=dict(title='Componente 1'),
                   autosize=False,
                   width=900,
                   height=900
                  )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id
# %%
bestDF[position_type].value_counts()\
                     .reset_index()\
                     .rename(columns={'index': position_type, position_type: '#Players'})\
                     .set_index(position_type)
# Out:
#                #Players
# Position Type
# Other              1778
# Midfielder         1035
# Defender            905
# Attacker            501
# Goalkeeper          293

# %% [markdown]
# Recordemos que la posición **Other** comprende a todos los jugadores suplentes y reservas.
# Es fundamental notar que estos jugadores también tienen posiciones definidas en sus equipos, por lo que es posible agruparlos observando sólo los valores de sus habilidades.

# %% [markdown]
# **GRAFICAMOS**
#
# Las variables que usamos para el *scatterplot* son las 2 componentes dadas por **tSNE**.
#
# Diferenciamos usando vectores booleanos para cada posición, y si es un jugador *top*.

# %%
bool_GK = bestDF[position_type] == 'Goalkeeper'

bool_D = bestDF[position_type] == 'Defender'

bool_M = bestDF[position_type] == 'Midfielder'

bool_A = bestDF[position_type] == 'Attacker'

# %%
palette = ['navy', 'red', 'yellow', 'green', 'skyblue']

attacker = go.Scatter(x=X_tsne[bool_A, 0],
                      y=X_tsne[bool_A, 1],
                      name='Attackers',
                      text=bestDF.loc[bool_A, name],
                      opacity=0.8,
                      marker=dict(color=palette[0], size=5),
                      mode='markers'
                     )

midfielder = go.Scatter(x=X_tsne[bool_M, 0],
                        y=X_tsne[bool_M, 1],
                        name='Midfielders',
                        text=bestDF.loc[bool_M, name],
                        opacity=0.7,
                        marker=dict(color=palette[1], size=5),
                        mode='markers'
                       )

defender = go.Scatter(x=X_tsne[bool_D, 0],
                      y=X_tsne[bool_D, 1],
                      name='Defenders',
                      text=bestDF.loc[bool_D, name],
                      opacity=0.7,
                      marker=dict(color=palette[2], size=5),
                      mode='markers'
                     )

goalkeeper = go.Scatter(x=X_tsne[bool_GK, 0],
                        y=X_tsne[bool_GK, 1],
                        name='Goalkeepers',
                        text=bestDF.loc[bool_GK, name],
                        opacity=0.5,
                        marker=dict(color=palette[3], size=5),
                        mode='markers'
                       )

top = go.Scatter(x=X_tsne[bool_TOP, 0],
                 y=X_tsne[bool_TOP, 1],
                 name='Top Players',
                 text=bestDF.loc[bool_TOP, name],
                 textfont=dict(family='sans serif', color='black', size=10),
                 opacity=0.9,
                 mode='text'
                )

data = [attacker, midfielder, defender, goalkeeper, top]

layout = go.Layout(title='t-SNE - FIFA Players',
                   titlefont=dict(size=20),
                   xaxis=dict(title='Componente 0'),
                   yaxis=dict(title='Componente 1'),
                   autosize=False,
                   width=900,
                   height=900
                  )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e9f2bcdb-9bf2-4960-b20c-72573743548b" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9f2bcdb-9bf2-4960-b20c-72573743548b")) {
#                     Plotly.newPlot(
#                         'e9f2bcdb-9bf2-4960-b20c-72573743548b',
#                         [{"marker": {"color": "navy", "size": 5}, "mode": "markers", "name": "Attackers", "opacity": 0.8, "text": ["Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala",
. Mateta", "M. Terrier", "G. Simeone", "O. Watkins", "H. Diallo", "G. Laborde", "F. Acheampong", "L. Ajorque", "A. \u0160porar", "L. Andersen", "M. Borja", "Negredo", "Soldado", "E. Elia", "Joselu", "A. Ayew", "N. Petersen", "Alan Kardec", "F. Smolov", "T. Pukki", "Kim Shin Wook", "F. Klos", "M. Uth", "S. Garc\u00eda", "S. Andersson", "\u00d3scar Plano", "F. Di Francesco", "M. Or\u0161i\u0107", "M. Boadu", "O. Edouard", "J. Mac\u00edas", "C. Baumgartner", "Arthur Cabral", "Toni Mart\u00ednez", "Bruno Tabata", "D. Rossi", "A. Morelos", "Y. Karamoh", "C. Kouam\u00e9", "E. \u00dcnal", "M. Zaccagni", "G. Kerk", "O. McBurnie", "R. Yaremchuk", "J. Locadia", "J. Dinenno", "Pedro Nuno", "R\u00faben Lameiras", "Trezeguet", "A. Cornelius", "J. Wallace", "O. Nguette", "F. Pizzini", "H. Mart\u00edn", "J. Sand", "R. Palacio", "G. Pell\u00e8", "H. Rodallega", "I. Scocco", "G. Bergessio", "Adri\u00e1n L\u00f3pez", "O. Toivonen", "S. Okaka", "R. Hennings", "N\u00e9lson Oliveira", "D. Quintero", "L. Rodr\u00edguez", "D. Didavi", "F. Jara", "M. Ga ...

# %% [markdown]
# Como conclusión, podemos ver que en este espacio 2D es realmente muy evidente la separación de los arqueros del resto de los jugadores (lo cual es lógico pues sus habilidades son muy diferentes).
#
# El agrupamiento visual del resto de jugadores, en este espacio, no es tan evidente pues los clusters no son disconexos.
#
# Las posiciones no explican tan claramente los clusters encontrados.
#
# Una explicación posible puede ser porque hay jugadores ambivalentes que unen los espacios entre defensa, mediocampo, y ataque.
#
# ¿Habrá otra explicación?¿Qué otras variables (que no estamos graficando) pueden explicar los grupos?
#
# ¿Cuántos grupos encontrará **MeanShift**, o cuales **KMeans**?

# %% [markdown]
# **Respuesta**
#
# Es una suposición bastante convincente que los jugadores ambivalentes sean los encargados de unir los agrupamientos de posiciones en el campo de los jugadores.
# Después de todo, se observa a los defensores en un extremo y a los atacantes en el otro extremo del gráfico.
# El grupo que parece hacer de puente de estos conjuntos es el de mediocampistas.
#
# Un defensor puede jugar más adelantado para aportar a la creación, mientras que un delantero puede jugar más atrasado para ayudar en la presión.
#
# A simple vista parece que no existen otros atributos, en el conjunto de datos, que puedan servir para separar a los jugadores del campo según sus posiciones.
# Quizás otras variables que podrían ser útiles en la visualización serían las relacionadas al desempeño (o vinculación) del jugador en cada una de las posiciones del juego (las últimas del *dataframe*).
# Claramente si adoptáramos este análisis nos estaríamos acercando a un problema supervisado.

# %% [markdown]
# # 4.Clustering_tSNE

# %% [markdown]
# **KMeans**
#
# Intentamos agrupar sobre los componentes de *tSNE*.
# Se define de forma arbitraria la cantidad de conjuntos a buscar.

# %%
# Número de clusters buscados.
n_clust = 4

km = KMeans(n_clusters=n_clust, random_state=123)
km.fit(X_tsne) # Utiliza todas las componentes: 2 dimensiones.

# Recuperación de las etiquetas.
clusters = km.labels_

print(f'Suma de los cuadrados de las distancias al cluster (Inertia) {km.inertia_}')
# Out:
# Suma de los cuadrados de las distancias al cluster (Inertia) 2062212.5046455387

# %%
clustersDF = bestDF.copy()
clustersDF[cluster_KMeans] = clusters.astype(str) # Clusters como Variables Categóricas
clustersDF[tsne_0] = X_tsne[:, 0]
clustersDF[tsne_1] = X_tsne[:, 1]

print(f'KMeans encontró {max(clusters) + 1} clusters (nosotros forzamos la cantidad)')
# Out:
# KMeans encontró 4 clusters (nosotros forzamos la cantidad)

# %%
fig = px.scatter(clustersDF,
                 x=tsne_0,
                 y=tsne_1,
                 color=cluster_KMeans,
                 hover_name=name,
                 hover_data=description,
                 symbol=player_class,
                 symbol_map={'TOP': 'star', 'Average': 'circle'},
                 title='Clustering KMeans',
                 height=800,
                 width=800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5bf69d3b-ca8c-40cb-9e37-16bca1a8c458" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5bf69d3b-ca8c-40cb-9e37-16bca1a8c458")) {
#                     Plotly.newPlot(
#                         '5bf69d3b-ca8c-40cb-9e37-16bca1a8c458',
#                         [{"customdata": [["L. Messi", 33, "Argentina", "FC Barcelona", "Spain Primera Division", "CAM", 93, 93], ["Cristiano Ronaldo", 35, "Portugal", "Juventus", "Italian Serie A", "LS", 92, 92], ["R. Lewandowski", 31, "Poland", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "ST", 91, 91], ["Neymar Jr", 28, "Brazil", "Paris Saint-Germain", "French Ligue 1", "LW", 91, 91], ["K. Mbapp\u00e9", 21, "France", "Paris Saint-Germain", "French Ligue 1", "LS", 90, 95], ["S. Man\u00e9", 28, "Senegal", "Liverpool", "English Premier League", "LW", 90, 90], ["M. Salah", 28, "Egypt", "Liverpool", "English Premier League", "RW", 90, 90], ["S. Ag\u00fcero", 32, "Argentina", "Manchester City", "English Premier League", "SUB", 89, 89], ["K. Benzema", 32, "France", "Real Madrid", "Spain Primera Division", "CF", 89, 89], ["R. Sterling", 25, "England", "Manchester City", "English Premier League", "LW", 88, 90], ["H. Kane", 26, "England", "Tottenham Hotspur", "English Premier League", "ST", 88, 89], ["P. Dybala", 26, "Argentina", "Juventus", "Italian Serie A", "RS", 88, 89], ["E. Hazard", 29, "Belgium", "Real Madrid", "Spain Primera Division", "LW", 88, 88], ["J. Sancho", 20, "England", "Borussia Dortmund", "German 1. Bundesliga", "RS", 87, 93], ["Bernardo Silva", 25, "Portugal", "Manchester City", "English Premier League", "LCM", 87, 88], ["L. Su\u00e1rez", 33, "Uruguay", "FC Barcelona", "Spain Primera Division", "SUB", 87, 87], ["P. Aubameyang", 31, "Gabon", "Arsenal", "English Premier League", "LW", 87, 87], ["C. Immobile", 30, "Italy", "Lazio", "Italian Serie A", "RS", 87, 87], ["A. Griezmann", 29, "France", "FC Barcelona", "Spain Primera Division", "ST", 87, 87], ["H. Son", 27, "Korea Republic", "Tottenham Hotspur", "English Premier League", "LM", 87, 87], ["Roberto Firmino", 28, "Brazil", "Liverpool", "English Premier League", "CF", 87, 87], ["A. G\u00f3mez", 32, "Argentina", "Atalanta", "Italian Serie A", "LF", 86, 86], ["David Silva", 34, "Spain", "Real Sociedad", "Spain Primera Division", "CAM", 86, 86], ["T. M\u00fcller", 30, "Germany", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "CAM", 86, 86], ["J. Vardy", 33, "England", "Leicester City", "English Premier League", "ST", 86, 86]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>KMeans=1<br>Player Class=TOP<br>TSNE_0=%{x}<br>TSNE_1=%{y}<br>short_name=%{customdata[0]}<br>age=%{customdata[1]}<br>nationality=%{customdata[2]}<br>club_name=%{customdata[3]}<br>league_name=%{customdata[4]}<br>team_position=%{customdata[5]}<br>overall=%{customdata[6]}<br>potential=%{customdata[7]}", "hovertext": ["L. Messi", "Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "S. Ag\u00fcero", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala", "E. Hazard", "J. Sancho", "Bernardo Silva", "L. Su\u00e1rez", "P. Aubameyang", "C. Immobile", "A. Griezmann", "H. Son", "Roberto Firmino", "A. G\u00f3mez", "David Silva", "T. M\u00fcller", "J. Vardy"], "legendgroup": "KMeans=1, Player Class=TOP", "marker": {"color": "#636efa", "symbol": "star"}, "mode": "markers", "name": "KMeans=1, Player Class=TOP", "showlegend": true, "type": "scattergl", "x": [48.92103958129883, 51.384037017822266, 52.64646911621094, 48.81389236450195, 50.54823303222656, 50.67501449584961, 49.716064453125, 51.735233306884766, 52.05276107788086, 39.924625396728516, 53.412635803222656, 48.22013473510742, 48.92286682128906, 36.922725677490234, 24.065711975097656, 53.66345977783203, 50.92741012573242, 58.57871627807617, 48.609737396240234, 50.094303131103516, 48.447044372558594, 28.1595458984375, 22.328516006469727, 47.12343978881836, 57.62834167480469], "xaxis": "x", "y": [14.606375694274902, 11.47669506072998, 11.556142807006836, 14.415253639221191, 9.666461944580078, 9.885255813598633, 9.459185600280762, 11.15563678741455, 11.574204444885254, -5.356876373291016, 11.67713737487793, 14.670668601989746, 14.214620590209961, -20.00038719177246, -17.984695434 ...

# %% [markdown]
# **Observación**
#
# Si intentamos analizar el gráfico exclusivamente de forma visual, **KMeans** obtiene un resultado satisfactorio.
# Separa el conjunto de los arqueros a la perfección y agrupa de forma más o menos convincente al resto de jugadores de campo (defensas, mediocampistas, delanteros).
#
# Es importante notar que **KMeans** solo contaba con los atributos obtenidos por *tSNE* (es decir, 2 dimensiones).
# Por lo que cualquier imperfección observable en el gráfico es causada por la reduccion de dimensionalidad previa.

# %% [markdown]
# **MeanShift**
#
# Intentamos agrupar sobre los componentes de tSNE.
# Al estimar el ancho de banda óptimo (`42.94`) para aplicar el agrupamiento, solo se encontraron **2** conjuntos.
# Debido que esto no es el resultado que se buscaba, se definió un valor arbitrario para efectuar el *clustering*.

# %%
# Estimate BW for MeanShift.
estimated_BW = estimate_bandwidth(X_tsne, random_state=123)
print(f'BandWidth Estimado: {estimated_BW}')

# Utilizamos el ancho de banda encontrado.
ms = MeanShift(bandwidth=estimated_BW, bin_seeding=True)
ms.fit(X_tsne) # Utiliza todas las componentes: 2 dimensiones.

# Recuperación de las etiquetas.
clusters = ms.labels_

print(f'MeanShift encontró {max(clusters) + 1} clusters (según los hiperparámetros elegidos)')
# Out:
# BandWidth Estimado: 42.93550849780112
# MeanShift encontró 2 clusters (según los hiperparámetros elegidos)

# %%
# Utilizamos un ancho de banda arbitrario.
ms = MeanShift(bandwidth=25, bin_seeding=True)
ms.fit(X_tsne) # Utiliza todas las habilidades: 2 dimensiones.

# Recuperación de las etiquetas.
clusters = ms.labels_

# %%
clustersDF[cluster_MeanShift] = clusters.astype(str) # Clusters como Variables Categóricas

print(f'MeanShift encontró {max(clusters) + 1} clusters (según los hiperparámetros elegidos)')
# Out:
# MeanShift encontró 4 clusters (según los hiperparámetros elegidos)

# %%
fig = px.scatter(clustersDF,
                 x=tsne_0,
                 y=tsne_1,
                 color=cluster_MeanShift,
                 hover_name=name,
                 hover_data=description,
                 symbol=player_class,
                 symbol_map={'TOP': 'star', 'Average': 'circle'},
                 title='Clustering MeanShift',
                 height=800,
                 width=800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b0df35e7-82da-4210-a57e-85d8f4032abc" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0df35e7-82da-4210-a57e-85d8f4032abc")) {
#                     Plotly.newPlot(
#                         'b0df35e7-82da-4210-a57e-85d8f4032abc',
#                         [{"customdata": [["L. Messi", 33, "Argentina", "FC Barcelona", "Spain Primera Division", "CAM", 93, 93], ["Cristiano Ronaldo", 35, "Portugal", "Juventus", "Italian Serie A", "LS", 92, 92], ["R. Lewandowski", 31, "Poland", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "ST", 91, 91], ["Neymar Jr", 28, "Brazil", "Paris Saint-Germain", "French Ligue 1", "LW", 91, 91], ["K. Mbapp\u00e9", 21, "France", "Paris Saint-Germain", "French Ligue 1", "LS", 90, 95], ["S. Man\u00e9", 28, "Senegal", "Liverpool", "English Premier League", "LW", 90, 90], ["M. Salah", 28, "Egypt", "Liverpool", "English Premier League", "RW", 90, 90], ["S. Ag\u00fcero", 32, "Argentina", "Manchester City", "English Premier League", "SUB", 89, 89], ["K. Benzema", 32, "France", "Real Madrid", "Spain Primera Division", "CF", 89, 89], ["R. Sterling", 25, "England", "Manchester City", "English Premier League", "LW", 88, 90], ["H. Kane", 26, "England", "Tottenham Hotspur", "English Premier League", "ST", 88, 89], ["P. Dybala", 26, "Argentina", "Juventus", "Italian Serie A", "RS", 88, 89], ["E. Hazard", 29, "Belgium", "Real Madrid", "Spain Primera Division", "LW", 88, 88], ["J. Sancho", 20, "England", "Borussia Dortmund", "German 1. Bundesliga", "RS", 87, 93], ["Bernardo Silva", 25, "Portugal", "Manchester City", "English Premier League", "LCM", 87, 88], ["L. Su\u00e1rez", 33, "Uruguay", "FC Barcelona", "Spain Primera Division", "SUB", 87, 87], ["A. Di Mar\u00eda", 32, "Argentina", "Paris Saint-Germain", "French Ligue 1", "RW", 87, 87], ["P. Aubameyang", 31, "Gabon", "Arsenal", "English Premier League", "LW", 87, 87], ["C. Immobile", 30, "Italy", "Lazio", "Italian Serie A", "RS", 87, 87], ["A. Griezmann", 29, "France", "FC Barcelona", "Spain Primera Division", "ST", 87, 87], ["H. Son", 27, "Korea Republic", "Tottenham Hotspur", "English Premier League", "LM", 87, 87], ["Roberto Firmino", 28, "Brazil", "Liverpool", "English Premier League", "CF", 87, 87], ["A. G\u00f3mez", 32, "Argentina", "Atalanta", "Italian Serie A", "LF", 86, 86], ["David Silva", 34, "Spain", "Real Sociedad", "Spain Primera Division", "CAM", 86, 86], ["T. M\u00fcller", 30, "Germany", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "CAM", 86, 86], ["J. Vardy", 33, "England", "Leicester City", "English Premier League", "ST", 86, 86]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>MeanShift=1<br>Player Class=TOP<br>TSNE_0=%{x}<br>TSNE_1=%{y}<br>short_name=%{customdata[0]}<br>age=%{customdata[1]}<br>nationality=%{customdata[2]}<br>club_name=%{customdata[3]}<br>league_name=%{customdata[4]}<br>team_position=%{customdata[5]}<br>overall=%{customdata[6]}<br>potential=%{customdata[7]}", "hovertext": ["L. Messi", "Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "S. Ag\u00fcero", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala", "E. Hazard", "J. Sancho", "Bernardo Silva", "L. Su\u00e1rez", "A. Di Mar\u00eda", "P. Aubameyang", "C. Immobile", "A. Griezmann", "H. Son", "Roberto Firmino", "A. G\u00f3mez", "David Silva", "T. M\u00fcller", "J. Vardy"], "legendgroup": "MeanShift=1, Player Class=TOP", "marker": {"color": "#636efa", "symbol": "star"}, "mode": "markers", "name": "MeanShift=1, Player Class=TOP", "showlegend": true, "type": "scattergl", "x": [48.92103958129883, 51.384037017822266, 52.64646911621094, 48.81389236450195, 50.54823303222656, 50.67501449584961, 49.716064453125, 51.735233306884766, 52.05276107788086, 39.924625396728516, 53.412635803222656, 48.22013473510742, 48.92286682128906, 36.922725677490234, 24.065711975097656, 53.66345977783203, 18.76961898803711, 50.92741012573242, 58.57871627807617, 48.609737396240234, 50.094303131103516, 48.447044372558594, 28.1595458984375, 22.328516006469727, 47.12343978881836, 57.62834167480469], "xaxis": "x", "y": [14.606375694274902, 11.47669506072998, 11.556142807006836, 14.415253639221191, 9.666461944580078, 9.885255813598633, 9.459185600280762, 11.155636 ...

# %% [markdown]
# **Observación**
#
# Los agrupamientos obtenidos son similares a los encontrados por *KMeans*,
#  el grupo de los defensores es más pequeño mientras que el grupo de los atacantes es más grande.
# Los conjuntos encontrados parecen bastante buenos y se separan bien.

# %% [markdown]
# # 5.Visualización_con_Embeddings_PCA

# %% [markdown]
# **PCA**
#
# Para reducción de dimensión, de **n** dimensiones a **m** dimensiones con $m << n$.
#
# **Ejemplo:** Vía Láctea en **3D**, [ejemplo 1](https://youtu.be/WNASVRwdf9Q) o [ejemplo 2](https://www.youtube.com/watch?v=S7GiZMVNB20), a Vía Láctea en **2D** (la proyección en 2D que mejor describe la dispersión de los datos).

# %% [markdown]
# **Variables de Desempeño (*skillRating*)**
#
# Retiramos a los arqueros, jugadores suplentes, jugadores reserva, y aquellos jugadores con un bajo `overall`.
# Complementamos el procesamiento restringiendo los datos a las variables numéricas que estudiaremos.

# %%
# Eliminamos posiciones no interesantes.
pcaDF = bestDF[~bestDF[position_type].isin(['Goalkeeper', 'Other'])]

onlySkills = []
for group, skills in skillRating.items():
    if group != 'goalkeeping':
        onlySkills += skills

onlySkills.remove('defending_marking')

# Sólo con desempeños según habilidades (no vacías).
skillsDF = pcaDF[onlySkills]

print(f'Dimensión del espacio de los datos: {len(onlySkills)}')
# Out:
# Dimensión del espacio de los datos: 28

# %% [markdown]
# **Se computan los Componentes Principales**
#
# Cuando se usa *decomposition.PCA*...
#
# La descomposición **PCA** de *sklearn* centra los datos pero no los estandariza (input data is centered but not scaled for each feature before applying the *SVD*).
# Por lo tanto, debemos **estandarizarlos**.

# %%
scaler = StandardScaler().fit(skillsDF)

# Numpy Array Estandarizado (le resta la media y divide por el desvío).
X_scaled = scaler.transform(skillsDF)

print(f'Sin Estandarización:\n{skillsDF.values[0]}')
print(f'Con Estandarización:\n{X_scaled[0]}')
# Out:
# Sin Estandarización:
# [85 95 70 91 88 35 24 96 93 94 91 96 86 68 72 69 94 91 80 91 94 95 44 40
#  93 95 75 96]
# Con Estandarización:
# [ 1.58781115  2.20983863  0.50663851  2.96692943  2.04581892 -1.24896221
#  -1.58679086  2.47696231  2.07928338  2.39957698  2.58133557  3.25363598
#   1.49720511 -0.11895272 -0.26194958 -0.10224895  2.14581975  1.61353507
#   0.76225029  1.66669751  3.71438729  2.0760533  -1.91634089 -1.00220432
#   1.9668365   2.43960413  1.20733223  3.48947098]

# %% [markdown]
# **DESCOMPOSICIÓN PCA**
#
# En la descomposición podemos elegir `n_components` para quedarnos con una cantidad chica de componentes.
# La idea es que sean bastante menos que la dimensión de lo datos pero que describan un buen porcentaje de la dispersión de los mismos.

# %%
# Elegimos 5, pero podrían ser más...
pca = PCA(n_components=5)

# Input data is centered but not scaled for each feature before applying the SVD.
pca.fit(X_scaled)

# Proporción de Varianza.
print(f'Proporción de Varianza por componente: {pca.explained_variance_ratio_}')
# Proporción de Varianza Acumulada.
print(f'Proporción de Varianza Acumulada por componente: {pca.explained_variance_ratio_.cumsum()}')

# Numpy Array Proyectado.
X_projected = pca.transform(X_scaled)
print(f'Tamaño del conjunto de datos: {X_projected.shape}')
# Out:
# Proporción de Varianza por componente: [0.41671552 0.14548482 0.11079231 0.06663965 0.03862529]
# Proporción de Varianza Acumulada por componente: [0.41671552 0.56220034 0.67299265 0.7396323  0.77825759]
# Tamaño del conjunto de datos: (2441, 5)

# %%
print(X_projected[:5]) # 5 primeros jugadores (con sus 'n_components').
# Out:
# [[-9.5157544  -2.96546631  1.36049839 -0.69240234  3.06442998]
#  [-7.50599741 -2.24306836  3.17656327 -4.17304796  1.74528267]
#  [-6.07776798 -2.49398721  3.74251881 -2.97256206  1.11498338]
#  [-9.08199913 -1.71675438  0.32273867 -0.73301999  2.71831111]
#  [-7.19803502 -5.47883076  0.83207263 -0.39625496  0.84130984]]

# %%
pcW = pca.components_ # Composición de las primeras componentes.

print(pcW) # Aporte de las variables skillRating.
# Out:
# [[-0.20292767 -0.24991836  0.12912988 -0.16421329 -0.23775176  0.16747922
#    0.17214502 -0.26083644 -0.24072233 -0.20904366 -0.08329056 -0.24541231
#   -0.2011293   0.07474732 -0.05275033  0.15238484 -0.24444176 -0.17208566
#   -0.13941488 -0.2153121  -0.10606959 -0.19078317  0.13392962  0.16021679
#   -0.25436772 -0.2424587  -0.20518684 -0.13271625]
#  [-0.11514953  0.06482762 -0.10284538 -0.32707351  0.01128914 -0.34527803
#   -0.3269021  -0.03481843 -0.09518063 -0.10305965 -0.36810085 -0.14764683
#   -0.08404933 -0.05311661 -0.16556146 -0.10311765 -0.06541643  0.15339898
#    0.16121839  0.08682569 -0.25563357  0.02744536 -0.27250197 -0.35399542
#    0.01638282 -0.15330118  0.00144866 -0.24873651]
#  [-0.20673092  0.19077885  0.32467749 -0.01936284  0.20870662 -0.1814757
#   -0.20528033 -0.07155398 -0.01758201  0.05415345 -0.09957057  0.00524093
#    0.21881949  0.04374953 -0.21208281  0.30673804  0.13505497 -0.30138718
#   -0.26177563 -0.27475846  0.11824026 -0.29733939  0.05311356 -0.17043416
#    0.08507449  0.00671958  0.2472446   0.18305973]
#  [ 0.03916789 -0.06766238 -0.32126665  0.08084996 -0.04250829  0.0113233
#   -0.00230678 -0.06589103  0.09177922  0.21850524  0.2121338  -0.02792423
#   -0.07299683 -0.48752695 -0.32271955 -0.23385852  0.03715136 -0.2944362
#   -0.37428963 -0.12289333 -0.22538275 -0.04767769 -0.22226781  0.01005485
#   -0.11297086  0.08858407  0.03418712 -0.08023709]
#  [-0.14361323 -0.06309331  0.06618945  0.22255948 -0.0507952  -0.08708198
#   -0.09644407  0.09185789 -0.19442814 -0.28152481  0.01361476  0.21696682
#   -0.30386565 -0.0947761  -0.315399   -0.15845321 -0.25427316  0.04288954
#    0.0098799   0.05376277  0.46136073  0.04998148 -0.22193294 -0.07149708
#   -0.06863243  0.01751894 -0.11532735  0.38189086]]

# %% [markdown]
# El siguiente gráfico muestra la composición de los pesos de las **dos** primeras componentes principales.

# %%
data = []

for i, (x, y) in enumerate(zip(pcW[0, :], pcW[1, :])):
    graph = go.Scatter(x=[0, x],
                       y=[0, y],
                       text=skillsDF.columns[i],
                       mode='lines+markers+text',
                       textposition='top left',
                       textfont=dict(family='sans serif', size=15)
                      )
    data.append(graph)

layout = go.Layout(title='PCA - FIFA Skills',
                   titlefont=dict(size=20),
                   xaxis=dict(title='Componente 0'),
                   yaxis=dict(title='Componente 1'),
                   autosize=False,
                   width=900,
                   height=900,
                   showlegend=False
                  )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ebe57e12-b6de-47f6-a3e4-9bb5dee902c4" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebe57e12-b6de-47f6-a3e4-9bb5dee902c4")) {
#                     Plotly.newPlot(
#                         'ebe57e12-b6de-47f6-a3e4-9bb5dee902c4',
#                         [{"mode": "lines+markers+text", "text": "attacking_crossing", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.20292766782761643], "y": [0, -0.11514952507778449]}, {"mode": "lines+markers+text", "text": "attacking_finishing", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.24991836277901094], "y": [0, 0.06482762065595453]}, {"mode": "lines+markers+text", "text": "attacking_heading_accuracy", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, 0.12912988113316703], "y": [0, -0.10284538044095404]}, {"mode": "lines+markers+text", "text": "attacking_short_passing", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.16421328766471777], "y": [0, -0.32707350587227413]}, {"mode": "lines+markers+text", "text": "attacking_volleys", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.23775175837112947], "y": [0, 0.011289137741936645]}, {"mode": "lines+markers+text", "text": "defending_standing_tackle", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, 0.167479224521858], "y": [0, -0.34527802716677003]}, {"mode": "lines+markers+text", "text": "defending_sliding_tackle", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, 0.17214502410946367], "y": [0, -0.32690210016858107]}, {"mode": "lines+markers+text", "text": "skill_dribbling", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.2608364396000833], "y": [0, -0.03481842519186388]}, {"mode": "lines+markers+text", "text": "skill_curve", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.24072232920392425], "y": [0, -0.09518062752801301]}, {"mode": "lines+markers+text", "text": "skill_fk_accuracy", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.20904365531595318], "y": [0, -0.10305964789331852]}, {"mode": "lines+markers+text", "text": "skill_long_passing", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.08329055704630293], "y": [0, -0.36810084954480105]}, {"mode": "lines+markers+text", "text": "skill_ball_control", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.24541230830914035], "y": [0, -0.14764682736360327]}, {"mode": "lines+markers+text", "text": "power_shot_power", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.20112929980565097], "y": [0, -0.08404932998040292]}, {"mode": "lines+markers+text", "text": "power_jumping", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, 0.07474731977283], "y": [0, -0.05311660824194165]}, {"mode": "lines+markers+text", "text": "power_stamina", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.052750326212221], "y": [0, -0.16556145777682116]}, {"mode": "lines+markers+text", "text": "power_strength", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, 0.1523848376107896], "y": [0, -0.10311764599189333]}, {"mode": "lines+markers+text", "text": "power_long_shots", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.24444175984473077], "y": [0, -0.06541642691271599]}, {"mode": "lines+markers+text", "text": "movement_acceleration", "textfont": {"family": "sans serif", "size": 15}, "textposition": "top left", "type": "scatter", "x": [0, -0.1720856557470922], "y": [0, 0 ...
#                         {"autosize": false, "height": 900, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0

# %% [markdown]
# **Observación**
#
# Notar que las habilidades forman una especie de *medialuna* en el plano.
#
# En sentido antihorario...
#
# - 1º cuadrante no aparecen habilidades, lo cual significa que los jugadores con habilidades altas **NO** aparecerán aquí. Debido que filtramos a los jugadores buenos, posiblemente este cuadrante esté bastante despoblado.
# - 2º cuadrante : `mentality_penalties`, `attacking_finishing`, `movement_acceleration` son  habilidades de atacantes, lo cual significa que los jugadores ofensivos *top* aparecerán aquí.
# - 3º cuadrante  `mentality_vision`, `power_long_shots`, `skill_ball_control) aparecen habilidades de mediocampistas, lo cual significa que los jugadores del medio campo *top* aparecerán aquí.
# - 4º cuadrante:   `defending_sliding_tackle`, `mentality_aggression`, `mentality_interceptions`,( habilidades de defensores) lo cual significa que los jugadores defensivos *top* aparecerán aquí.
#
# Todas estas observaciones se evidenciarán en el siguiente gráfico.

# %% [markdown]
# **Graficamos a los jugadores usando las dos primeras componentes de PCA**
#
# Proyectamos los datos (de **dim 28**) en ese nuevo espacio (de **dim 2**).
#
# Identificamos a un jugador en particular, por ejemplo, Lionel Messi.

# %%
# Elegimos a nuestro jugador.
bool_PLAYER = pcaDF[name] == 'L. Messi'

# Diferenciamos a los mejores jugadores.
bool_TOP = pcaDF[overall] > topOverall

# %%
top = go.Scatter(x=X_projected[bool_TOP, 0],
                 y=X_projected[bool_TOP, 1],
                 name='Top Players',
                 text=pcaDF.loc[bool_TOP, name],
                 textfont=dict(family='sans serif', size=8, color='black'),
                 opacity=0.9,
                 marker=dict(color=palette[0], size=6),
                 mode='markers+text'
                )

average = go.Scatter(x=X_projected[~bool_TOP, 0],
                     y=X_projected[~bool_TOP, 1],
                     name='Average Players',
                     text=pcaDF.loc[~bool_TOP, name],
                     opacity=0.6,
                     marker=dict(color=palette[1], size=4),
                     mode='markers'
                    )

player = go.Scatter(x=X_projected[bool_PLAYER, 0],
                    y=X_projected[bool_PLAYER, 1],
                    name='Searched Player',
                    text=pcaDF.loc[bool_PLAYER, name],
                    textfont=dict(family='sans serif', size=10, color='black'),
                    opacity=1,
                    marker=dict(color=palette[4], size=20),
                    mode='markers+text'
                   )

data = [average, top, player]

layout = go.Layout(title='PCA - FIFA Players',
                   titlefont=dict(size=20),
                   xaxis=dict(title='Componente 0'),
                   yaxis=dict(title='Componente 1'),
                   autosize=False,
                   width=900,
                   height=900
                  )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ca6e1514-1410-4f54-a2dd-f3276185ef06" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca6e1514-1410-4f54-a2dd-f3276185ef06")) {
#                     Plotly.newPlot(
#                         'ca6e1514-1410-4f54-a2dd-f3276185ef06',
#                         [{"marker": {"color": "red", "size": 4}, "mode": "markers", "name": "Average Players", "opacity": 0.6, "text": ["K. Havertz", "M. Rashford", "L. San\u00e9", "F. de Jong", "Marquinhos", "C. Lenglet", "S. Milinkovi\u0107-Savi\u0107", "M. \u0160kriniar", "M. Depay", "T. Werner", "Rodri", "S. Gnabry", "R. Lukaku", "Luis Alberto", "M. Icardi", "D. Mertens", "M. Pjani\u0107", "G. Wijnaldum", "D. God\u00edn", "T. Alderweireld", "L. Bonucci", "M. Reus", "K. Walker", "Parejo", "C. Eriksen", "Koke", "L. Insigne", "R. Mahrez", "E. Haaland", "L. Mart\u00ednez", "Oyarzabal", "L. Goretzka", "Grimaldo", "A. Martial", "J. Gim\u00e9nez", "W. Ndidi", "Sa\u00fal", "S. de Vrij", "L. Digne", "R. Guerreiro", "T. Partey", "Alex Telles", "M. Brozovi\u0107", "Fernandinho", "Jes\u00fas Navas", "Lucas Leiva", "A. Witsel", "Azpilicueta", "Iago Aspas", "J. Corona", "I. Gueye", "D. Alaba", "Pizzi", "W. Ben Yedder", "J. Ili\u010di\u0107", "R. Jim\u00e9nez", "Felipe", "N. Tagliafico", "O. Demb\u00e9l\u00e9", "Gay\u00e0", "J. Gomez", "F. Mendy", "A. Wan-Bissaka", "A. Hakimi", "A. Romagnoli", "D. Zakaria", "Gabriel Jesus", "N\u00e9lson Semedo", "M. Sabitzer", "Diego Carlos", "K. Manolas", "N. Fekir", "Z. Ibrahimovi\u0107", "Jo\u00e3o Moutinho", "G. Higua\u00edn", "Renato Augusto", "C. Vela", "B. Matuidi", "J. Vertonghen", "E. Banega", "E. D\u017eeko", "Fernando", "K. Trippier", "Paulinho", "Oscar", "Muniain", "A. Lacazette", "W. Zaha", "C. Ar\u00e1nguiz", "D. Tadi\u0107", "F. Acerbi", "Allan", "Lucas Moura", "Portu", "Jorginho", "E. Vi\u0161\u0107a", "Gerard Moreno", "F. Kosti\u0107", "D. Zapata", "Rafa", "Ronaldo Cabrais", "Fabi\u00e1n", "R\u00faben Neves", "G. Lo Celso", "K. Laimer", "H. Maguire", "Anderson Talisca", "A. Correa", "N. P\u00e9p\u00e9", "E. Can", "Morata", "Gabriel Paulista", "L. Ocampos", "M. Ginter", "D. Djen\u00e9", "Ra\u00fal Albiol", "I. Rakiti\u0107", "D. Payet", "L. Bender", "
# - En el 3º cuadrante tenemos mediocampistas *top*, como *De Bruyne*,  *Kroos*. Aunque también se filtraron delanteros, como *Ronaldo*, . Otro testimonio sobre la ambivalencia de los jugadores.
# - En el 4º cuadrante tenemos defensores *top*, como *Van Dijk*, *Piqué*, *Chiellini*.

# %% [markdown]
# **Graficamos a los jugadores usando las dos primeras componentes de PCA**
#
# Proyectamos los datos (de **dim 28**) en ese nuevo espacio (de **dim 2**).
#
# Ahora también identificamos su posición en el campo de juego.

# %%
bool_D = pcaDF[position_type] == 'Defender'

bool_M = pcaDF[position_type] == 'Midfielder'

bool_A = pcaDF[position_type] == 'Attacker'

# %%
attacker = go.Scatter(x=X_projected[bool_A, 0],
                      y=X_projected[bool_A, 1],
                      name='Attackers',
                      text=pcaDF.loc[bool_A, name],
                      opacity=0.8,
                      marker=dict(color=palette[0], size=5),
                      mode='markers'
                     )

midfielder = go.Scatter(x=X_projected[bool_M, 0],
                        y=X_projected[bool_M, 1],
                        name='Midfielders',
                        text=pcaDF.loc[bool_M, name],
                        opacity=0.7,
                        marker=dict(color=palette[1], size=5),
                        mode='markers'
                       )

defender = go.Scatter(x=X_projected[bool_D, 0],
                      y=X_projected[bool_D, 1],
                      name='Defenders',
                      text=pcaDF.loc[bool_D, name],
                      opacity=0.6,
                      marker=dict(color=palette[2], size=5),
                      mode='markers'
                     )

top = go.Scatter(x=X_projected[bool_TOP, 0],
                 y=X_projected[bool_TOP, 1],
                 name='Top Players',
                 text=pcaDF.loc[bool_TOP, name],
                 textfont=dict(family='sans serif', color='black', size=10),
                 opacity=0.9,
                 mode='text'
                )

data = [attacker, midfielder, defender, top]

layout = go.Layout(title='PCA - FIFA Players',
                   titlefont=dict(size=20),
                   xaxis=dict(title='Componente 0'),
                   yaxis=dict(title='Componente 1'),
                   autosize=False,
                   width=900,
                   height=900
                  )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ad539e1b-552e-4dc6-be96-cd765a4b0c7e" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad539e1b-552e-4dc6-be96-cd765a4b0c7e")) {
#                     Plotly.newPlot(
#                         'ad539e1b-552e-4dc6-be96-cd765a4b0c7e',
#                         [{"marker": {"color": "navy", "size": 5}, "mode": "markers", "name": "Attackers", "opacity": 0.8, "text": ["Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala", "E. Hazard", "J. Sancho", "A. Di Mar\u00eda", "P. Aubameyang", "C. Immobile", "A. Griezmann", "Roberto Firmino", "A. G\u00f3mez", "J. Vardy", "M. Depay", "T. Werner", "R. Lukaku", "M. Icardi", "D. Mertens", "L. Insigne", "R. Mahrez", "E. Haaland", "L. Mart\u00ednez", "Oyarzabal", "A. Martial", "Iago Aspas", "W. Ben Yedder", "J. Ili\u010di\u0107", "R. Jim\u00e9nez", "O. Demb\u00e9l\u00e9", "Gabriel Jesus", "Z. Ibrahimovi\u0107", "G. Higua\u00edn", "C. Vela", "E. D\u017eeko", "A. Lacazette", "W. Zaha", "D. Tadi\u0107", "Portu", "Gerard Moreno", "D. Zapata", "Ronaldo Cabrais", "N. P\u00e9p\u00e9", "Morata", "L. Ocampos", "D. Payet", "M. Arnautovi\u0107", "J. Rodr\u00edguez", "F. Thauvin", "A. Kramari\u0107", "Jo\u00e3
", "A. Morelos", "Y. Karamoh", "C. Kouam\u00e9", "E. \u00dcnal", "M. Zaccagni", "G. Kerk", "O. McBurnie", "R. Yaremchuk", "J. Locadia", "J. Dinenno", "Pedro Nuno", "R\u00faben Lameiras", "Trezeguet", "A. Cornelius", "J. Wallace", "O. Nguette", "F. Pizzini", "H. Mart\u00edn", "J. Sand", "R. Palacio", "G. Pell\u00e8", "H. Rodallega", "I. Scocco", "G. Bergessio", "Adri\u00e1n L\u00f3pez", "O. Toivonen", "S. Okaka", "R. Hennings", "N\u00e9lson Oliveira", "D. Quintero", "L. Rodr\u00edguez", "D. Didavi", "F. Jara", "M. Ga ...

# %% [markdown]
# # 6.Clustering_PCA

# %% [markdown]
# agrupamientos de los jugadores usando las primeras componentes.

# %% [markdown]
# **KMeans**
#
# Intentamos agrupar sobre las primeras componentes de *PCA*.
# Se define de forma arbitraria la cantidad de conjuntos a buscar.

# %%
# Número de clusters buscados.
n_clust = 3

km = KMeans(n_clusters=n_clust, random_state=123)
km.fit(X_projected) # Utiliza todas las componentes: 5 dimensiones.

# Recuperación de las etiquetas.
clusters = km.labels_

print(f'Suma de los cuadrados de las distancias al cluster (Inertia) {km.inertia_}')
# Out:
# Suma de los cuadrados de las distancias al cluster (Inertia) 26573.509962059623

# %%
clustersDF = pcaDF.copy()
clustersDF[cluster_KMeans] = clusters.astype(str) # Clusters como Variables Categóricas
clustersDF[pca_0] = X_projected[:, 0]
clustersDF[pca_1] = X_projected[:, 1]

print(f'KMeans encontró {max(clusters) + 1} clusters (nosotros forzamos la cantidad)')
# Out:
# KMeans encontró 3 clusters (nosotros forzamos la cantidad)

# %%
fig = px.scatter(clustersDF,
                 x=pca_0,
                 y=pca_1,
                 color=cluster_KMeans,
                 hover_name=name,
                 hover_data=description,
                 symbol=player_class,
                 symbol_map={'TOP': 'star', 'Average': 'circle'},
                 title='Clustering KMeans',
                 height=800,
                 width=800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6eb35b35-0f27-465f-9dff-d62115f77d17" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6eb35b35-0f27-465f-9dff-d62115f77d17")) {
#                     Plotly.newPlot(
#                         '6eb35b35-0f27-465f-9dff-d62115f77d17',
#                         [{"customdata": [["L. Messi", 33, "Argentina", "FC Barcelona", "Spain Primera Division", "CAM", 93, 93], ["Cristiano Ronaldo", 35, "Portugal", "Juventus", "Italian Serie A", "LS", 92, 92], ["R. Lewandowski", 31, "Poland", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "ST", 91, 91], ["Neymar Jr", 28, "Brazil", "Paris Saint-Germain", "French Ligue 1", "LW", 91, 91], ["K. Mbapp\u00e9", 21, "France", "Paris Saint-Germain", "French Ligue 1", "LS", 90, 95], ["S. Man\u00e9", 28, "Senegal", "Liverpool", "English Premier League", "LW", 90, 90], ["M. Salah", 28, "Egypt", "Liverpool", "English Premier League", "RW", 90, 90], ["K. Benzema", 32, "France", "Real Madrid", "Spain Primera Division", "CF", 89, 89], ["R. Sterling", 25, "England", "Manchester City", "English Premier League", "LW", 88, 90], ["H. Kane", 26, "England", "Tottenham Hotspur", "English Premier League", "ST", 88, 89], ["P. Dybala", 26, "Argentina", "Juventus", "Italian Serie A", "RS", 88, 89], ["E. Hazard", 29, "Belgium", "Real Madrid", "Spain Primera Division", "LW", 88, 88], ["J. Sancho", 20, "England", "Borussia Dortmund", "German 1. Bundesliga", "RS", 87, 93], ["Bernardo Silva", 25, "Portugal", "Manchester City", "English Premier League", "LCM", 87, 88], ["A. Di Mar\u00eda", 32, "Argentina", "Paris Saint-Germain", "French Ligue 1", "RW", 87, 87], ["P. Aubameyang", 31, "Gabon", "Arsenal", "English Premier League", "LW", 87, 87], ["C. Immobile", 30, "Italy", "Lazio", "Italian Serie A", "RS", 87, 87], ["A. Griezmann", 29, "France", "FC Barcelona", "Spain Primera Division", "ST", 87, 87], ["H. Son", 27, "Korea Republic", "Tottenham Hotspur", "English Premier League", "LM", 87, 87], ["Roberto Firmino", 28, "Brazil", "Liverpool", "English Premier League", "CF", 87, 87], ["A. G\u00f3mez", 32, "Argentina", "Atalanta", "Italian Serie A", "LF", 86, 86], ["David Silva", 34, "Spain", "Real Sociedad", "Spain Primera Division", "CAM", 86, 86], ["J. Vardy", 33, "England", "Leicester City", "English Premier League", "ST", 86, 86]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>KMeans=2<br>Player Class=TOP<br>PCA_0=%{x}<br>PCA_1=%{y}<br>short_name=%{customdata[0]}<br>age=%{customdata[1]}<br>nationality=%{customdata[2]}<br>club_name=%{customdata[3]}<br>league_name=%{customdata[4]}<br>team_position=%{customdata[5]}<br>overall=%{customdata[6]}<br>potential=%{customdata[7]}", "hovertext": ["L. Messi", "Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala", "E. Hazard", "J. Sancho", "Bernardo Silva", "A. Di Mar\u00eda", "P. Aubameyang", "C. Immobile", "A. Griezmann", "H. Son", "Roberto Firmino", "A. G\u00f3mez", "David Silva", "J. Vardy"], "legendgroup": "KMeans=2, Player Class=TOP", "marker": {"color": "#636efa", "symbol": "star"}, "mode": "markers", "name": "KMeans=2, Player Class=TOP", "showlegend": true, "type": "scattergl", "x": [-9.51575439655321, -7.505997409297973, -6.077767982696459, -9.081999126463385, -6.75577022757085, -6.37572526837939, -7.155268021081566, -6.17715919134459, -6.5572324726362785, -5.3753300487151945, -7.78239337085404, -7.867214954757842, -6.3963400367809085, -6.599354252531493, -6.613346749619962, -5.709720745294075, -4.652102653673024, -6.641648677347292, -6.931155466493273, -5.574473010825898, -7.320035985375391, -6.550526294238055, -3.6744272193750303], "xaxis": "x", "y": [-2.9654663072850003, -2.243068358170975, -2.4939872137846693, -1.7167543787915127, -1.066209056408323, -1.8548796556011267, -2.1150512317638364, -1.993251325446633, -0.6482677304984592, -3.082319431473525, -1.600977782183474, -1.1628923539126348, -0.37547540829096004, -2.310722657638165, -2.4087043676194, -0.1510798078002312, -0.33981100849618523, -3.4981421948887923, -1.293589614898003, -3.518174221325743, -0.5736426864671499, -2.831947238515475, -0.4681594179992134], "yaxis": "y"}, {"customdata": [["K. Havertz", 21, "Germany", "Chels ...

# %% [markdown]
# **Observación**
#
#  **KMeans** separa los tres conjuntos de jugadores de campo de forma mas o menos satisfactoria.
# se obtuvo un agrupamiento mucho mejor cuando se aplicó *clustering* sobre el resultado del *embedding* de *tSNE*.

# %% [markdown]
# **MeanShift**
#
# Intentamos agrupar sobre los componentes de *PCA*.
# Al estimar el ancho de banda óptimo (`4.85`) para aplicar el agrupamiento, solo se encontró **1** conjunto.
# Debido que esto no es el resultado que se buscaba, se definió un valor arbitrario para efectuar el *clustering*.

# %%
# Estimate BW for MeanShift.
estimated_BW = estimate_bandwidth(X_projected, random_state=123)
print(f'BandWidth Estimado: {estimated_BW}')

# Utilizamos el ancho de banda encontrado.
ms = MeanShift(bandwidth=estimated_BW, bin_seeding=True)
ms.fit(X_projected) # Utiliza todas las componentes: 5 dimensiones.

# Recuperación de las etiquetas.
clusters = ms.labels_

print(f'MeanShift encontró {max(clusters) + 1} clusters (según los hiperparámetros elegidos)')
# Out:
# BandWidth Estimado: 4.8500079646854095
# MeanShift encontró 1 clusters (según los hiperparámetros elegidos)

# %%
# Utilizamos un ancho de banda arbitrario.
ms = MeanShift(bandwidth=2.75, bin_seeding=True)
ms.fit(X_projected) # Utiliza todas las componentes: 5 dimensiones.

# Recuperación de las etiquetas.
clusters = ms.labels_

# %%
clustersDF[cluster_MeanShift] = clusters.astype(str) # Clusters como Variables Categóricas

print(f'MeanShift encontró {max(clusters) + 1} clusters (según los hiperparámetros elegidos)')
# Out:
# MeanShift encontró 3 clusters (según los hiperparámetros elegidos)

# %%
fig = px.scatter(clustersDF,
                 x=pca_0,
                 y=pca_1,
                 color=cluster_MeanShift,
                 hover_name=name,
                 hover_data=description,
                 symbol=player_class,
                 symbol_map={'TOP': 'star', 'Average': 'circle'},
                 title='Clustering MeanShift',
                 height=800,
                 width=800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3808d0df-83db-423d-805b-31aeefeab9d0" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3808d0df-83db-423d-805b-31aeefeab9d0")) {
#                     Plotly.newPlot(
#                         '3808d0df-83db-423d-805b-31aeefeab9d0',
#                         [{"customdata": [["L. Messi", 33, "Argentina", "FC Barcelona", "Spain Primera Division", "CAM", 93, 93], ["Cristiano Ronaldo", 35, "Portugal", "Juventus", "Italian Serie A", "LS", 92, 92], ["R. Lewandowski", 31, "Poland", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "ST", 91, 91], ["Neymar Jr", 28, "Brazil", "Paris Saint-Germain", "French Ligue 1", "LW", 91, 91], ["K. De Bruyne", 29, "Belgium", "Manchester City", "English Premier League", "RCM", 91, 91], ["K. Mbapp\u00e9", 21, "France", "Paris Saint-Germain", "French Ligue 1", "LS", 90, 95], ["S. Man\u00e9", 28, "Senegal", "Liverpool", "English Premier League", "LW", 90, 90], ["M. Salah", 28, "Egypt", "Liverpool", "English Premier League", "RW", 90, 90], ["K. Benzema", 32, "France", "Real Madrid", "Spain Primera Division", "CF", 89, 89], ["R. Sterling", 25, "England", "Manchester City", "English Premier League", "LW", 88, 90], ["H. Kane", 26, "England", "Tottenham Hotspur", "English Premier League", "ST", 88, 89], ["P. Dybala", 26, "Argentina", "Juventus", "Italian Serie A", "RS", 88, 89], ["T. Kroos", 30, "Germany", "Real Madrid", "Spain Primera Division", "LCM", 88, 88], ["E. Hazard", 29, "Belgium", "Real Madrid", "Spain Primera Division", "LW", 88, 88], ["J. Sancho", 20, "England", "Borussia Dortmund", "German 1. Bundesliga", "RS", 87, 93], ["Bruno Fernandes", 25, "Portugal", "Manchester United", "English Premier League", "CAM", 87, 90], ["Bernardo Silva", 25, "Portugal", "Manchester City", "English Premier League", "LCM", 87, 88], ["L. Modri\u0107", 34, "Croatia", "Real Madrid", "Spain Primera Division", "RCM", 87, 87], ["A. Di Mar\u00eda", 32, "Argentina", "Paris Saint-Germain", "French Ligue 1", "RW", 87, 87], ["P. Aubameyang", 31, "Gabon", "Arsenal", "English Premier League", "LW", 87, 87], ["C. Immobile", 30, "Italy", "Lazio", "Italian Serie A", "RS", 87, 87], ["A. Griezmann", 29, "France", "FC Barcelona", "Spain Primera Division", "ST", 87, 87], ["H. Son", 27, "Korea Republic", "Tottenham Hotspur", "English Premier League", "LM", 87, 87], ["Roberto Firmino", 28, "Brazil", "Liverpool", "English Premier League", "CF", 87, 87], ["A. G\u00f3mez", 32, "Argentina", "Atalanta", "Italian Serie A", "LF", 86, 86], ["David Silva", 34, "Spain", "Real Sociedad", "Spain Primera Division", "CAM", 86, 86], ["T. M\u00fcller", 30, "Germany", "FC Bayern M\u00fcnchen", "German 1. Bundesliga", "CAM", 86, 86], ["J. Vardy", 33, "England", "Leicester City", "English Premier League", "ST", 86, 86]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>MeanShift=1<br>Player Class=TOP<br>PCA_0=%{x}<br>PCA_1=%{y}<br>short_name=%{customdata[0]}<br>age=%{customdata[1]}<br>nationality=%{customdata[2]}<br>club_name=%{customdata[3]}<br>league_name=%{customdata[4]}<br>team_position=%{customdata[5]}<br>overall=%{customdata[6]}<br>potential=%{customdata[7]}", "hovertext": ["L. Messi", "Cristiano Ronaldo", "R. Lewandowski", "Neymar Jr", "K. De Bruyne", "K. Mbapp\u00e9", "S. Man\u00e9", "M. Salah", "K. Benzema", "R. Sterling", "H. Kane", "P. Dybala", "T. Kroos", "E. Hazard", "J. Sancho", "Bruno Fernandes", "Bernardo Silva", "L. Modri\u0107", "A. Di Mar\u00eda", "P. Aubameyang", "C. Immobile", "A. Griezmann", "H. Son", "Roberto Firmino", "A. G\u00f3mez", "David Silva", "T. M\u00fcller", "J. Vardy"], "legendgroup": "MeanShift=1, Player Class=TOP", "marker": {"color": "#636efa", "symbol": "star"}, "mode": "markers", "name": "MeanShift=1, Player Class=TOP", "showlegend": true, "type": "scattergl", "x": [-9.51575439655321, -7.505997409297973, -6.077767982696459, -9.081999126463385, -7.198035017096989, -6.75577022757085, -6.37572526837939, -7.155268021081566, -6.17715919134459, -6.5572324726362785, -5.3753300487151945, -7.78239337085404, -5.193831390709851, -7.867214954757842, -6.3963400367809085, -6.474395260024431, -6.599354252531493, -6.171187765853207, -6.613346749619962, -5.709720745294075, -4.652102653673024, -6.641648677347292, -6.931155466493273, -5. ...

# %% [markdown]
# ANALISIS
#
#
# conjunto de datos es SEPARADO en dos grandes grupos  donde hay jugadores ofensivos de un lado y jugadores defensivos del otro. Peor aparece un TERCER GRUPO (verde) que no se puede explicar muy bien (es raro). Son adatos dispersos sin aparente  relación
